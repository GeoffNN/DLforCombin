# %%
import matplotlib.pyplot as plt
# import pandas as pd
import numpy as np
# %matplotlib inline

# %%
np.loadtxt('data/Knapsack11-29-2017-00:56:1511945761/log.txt', skiprows=1)[0:10, :]
# Out:
# array([[  6.00000000e+04,   2.90053156e+00,   3.39712945e+00,
#           4.19175334e+00,   6.30519481e-01,             -inf,
#           1.54000000e+02,   9.46000000e-01],
#        [  7.00000000e+04,   2.86889198e+00,   3.33933430e+00,
#           4.19733456e+00,   6.19536424e-01,             -inf,
#           3.02000000e+02,   9.37000000e-01],
#        [  8.00000000e+04,   2.89985770e+00,   3.35348784e+00,
#           4.20446640e+00,   6.24122807e-01,             -inf,
#           4.56000000e+02,   9.28000000e-01],
#        [  9.00000000e+04,   2.85788623e+00,   3.30452095e+00,
#           4.16692347e+00,   6.21052632e-01,             -inf,
#           6.27000000e+02,   9.19000000e-01],
#        [  1.00000000e+05,   2.86729559e+00,   3.28241510e+00,
#           4.15454827e+00,   6.18134715e-01,             -inf,
#           7.72000000e+02,   9.10000000e-01],
#        [  1.10000000e+05,   2.84987716e+00,   3.26195545e+00,
# ...

# %%
logfile = 'data/Knapsack11-29-2017-12:15:1511986558/log.txt'
logfile2 = 'data/Knapsack11-29-2017-12:23:1511987007/log.txt'
logfile3 = 'data/Knapsack11-29-2017-12:37:1511987830/log.txt'
logfile4 = 'data/Knapsack11-29-2017-12:41:1511988079/log.txt'
logfile5 = 'data/Knapsack11-29-2017-12:58:1511989098/log.txt'
logfile6 = 'data/Knapsack11-29-2017-18:12:1512007959/log.txt'
logfile7 = 'data/Knapsack11-29-2017-23:55:1512028534/log.txt'
logfile8 = 'data/Knapsack11-30-2017-01:08:1512032939/log.txt'

# %%
plt.plot(np.loadtxt(logfile, skiprows=1)[:, 0], np.loadtxt(logfile, skiprows=1)[:, 4],
        label = '2layers-64hunits-32batch_size-run1')
#plt.plot(np.loadtxt(logfile2, skiprows=1)[:, 0], np.loadtxt(logfile2, skiprows=1)[:, 4],
#        label = '3layers-64hunits-32batch_size')
#plt.plot(np.loadtxt(logfile3, skiprows=1)[:, 0], np.loadtxt(logfile3, skiprows=1)[:, 4],
#        label = '2layers-64hunits-32batch_size-run2')
#plt.plot(np.loadtxt(logfile4, skiprows=1)[:, 0], np.loadtxt(logfile4, skiprows=1)[:, 4],
#        label = '2layers-64hunits-32batch_size-run3-withSummaries')
#plt.plot(np.loadtxt(logfile5, skiprows=1)[:, 0], np.loadtxt(logfile5, skiprows=1)[:, 4],
#        label = '2layers-64hunits-32batch_size-run4-withSummaries+modelSaver')
#plt.plot(np.loadtxt(logfile6, skiprows=1)[:, 0], np.loadtxt(logfile6, skiprows=1)[:, 4],
#        label = '6layers-128hunits-32batch_size-run4-doubleDQN')
plt.plot(np.loadtxt(logfile7, skiprows=1)[:, 0], np.loadtxt(logfile7, skiprows=1)[:, 4],
        label = '2layers-64hunits-32batch_size-NoReplay')
plt.plot(np.loadtxt(logfile8, skiprows=1)[:, 0], np.loadtxt(logfile8, skiprows=1)[:, 4],
        label = '2layers-64hunits-32batch_size-NR-3sa')
plt.xlabel('Environment steps')
plt.ylabel('Knapsack accuracy')
plt.legend()
plt.show()

# %%
logfile1 = 'data/data/Knapsack_PG30-11-2017_18-14-09/1/log.txt'
logfile2 = 'data/data/Knapsack_PG30-11-2017_18-28-25/1/log.txt'

# %%
# Accuracy PG
plt.plot(np.loadtxt(logfile1, skiprows=1)[:, 1], np.loadtxt(logfile1, skiprows=1)[:, 3],
         label='b=1000')
plt.plot(np.loadtxt(logfile2, skiprows=1)[:, 1], np.loadtxt(logfile2, skiprows=1)[:, 3],
         label='b=5000')

# %%
np.array([np.ones((2,2)), np.ones((2,2))])
# Out:
# array([[[ 1.,  1.],
#         [ 1.,  1.]],
#
#        [[ 1.,  1.],
#         [ 1.,  1.]]])

# %%
# Return PG
plt.plot(np.loadtxt(logfile1, skiprows=1)[:, 1], np.loadtxt(logfile1, skiprows=1)[:, 2],
         label='b=1000')
plt.plot(np.loadtxt(logfile2, skiprows=1)[:, 1], np.loadtxt(logfile2, skiprows=1)[:, 2],
         label='b=1000')
