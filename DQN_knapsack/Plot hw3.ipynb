# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
np.loadtxt('data/lr0.5/log.txt', skiprows=1)[:, 0]
# Out:
# array([   10000.,    20000.,    30000.,    40000.,    50000.,    60000.,
#           70000.,    80000.,    90000.,   100000.,   110000.,   120000.,
#          130000.,   140000.,   150000.,   160000.,   170000.,   180000.,
#          190000.,   200000.,   210000.,   220000.,   230000.,   240000.,
#          250000.,   260000.,   270000.,   280000.,   290000.,   300000.,
#          310000.,   320000.,   330000.,   340000.,   350000.,   360000.,
#          370000.,   380000.,   390000.,   400000.,   410000.,   420000.,
#          430000.,   440000.,   450000.,   460000.,   470000.,   480000.,
#          490000.,   500000.,   510000.,   520000.,   530000.,   540000.,
#          550000.,   560000.,   570000.,   580000.,   590000.,   600000.,
#          610000.,   620000.,   630000.,   640000.,   650000.,   660000.,
#          670000.,   680000.,   690000.,   700000.,   710000.,   720000.,
#          730000.,   740000.,   750000.,   760000.,   770000.,   780000.,
# ...

# %%
plt.plot(np.loadtxt('data/lr10/log.txt', skiprows=1)[:, 0], np.loadtxt('data/lr10/log.txt', skiprows=1)[:, 1],
        label = 'lr10')
plt.plot(np.loadtxt('data/lr0.5/log.txt', skiprows=1)[:, 0], np.loadtxt('data/lr0.5/log.txt', skiprows=1)[:, 1],
        label = 'lr0.5')
plt.plot(np.loadtxt('data/lr1.0/log.txt', skiprows=1)[:, 0], np.loadtxt('data/lr1.0/log.txt', skiprows=1)[:, 1],
        label = 'lr1.0')
plt.plot(np.loadtxt('data/lr1.0/log.txt', skiprows=1)[:, 0], np.loadtxt('data/lr1.0/log.txt', skiprows=1)[:, 1],
        label = 'lr1.0')
plt.plot(np.loadtxt('data/lr5.0/log.txt', skiprows=1)[:, 0], np.loadtxt('data/lr5.0/log.txt', skiprows=1)[:, 1],
        label = 'lr5.0')
plt.plot(np.loadtxt('data/tuf1000/log.txt', skiprows=1)[:, 0], np.loadtxt('data/tuf1000/log.txt', skiprows=1)[:, 1],
        label = 'tuf1000')
plt.plot(np.loadtxt('data/tuf20000/log.txt', skiprows=1)[:, 0], np.loadtxt('data/tuf20000/log.txt', skiprows=1)[:, 1],
        label = 'tuf20000')
plt.plot(np.loadtxt('data/tuf5000/log.txt', skiprows=1)[:, 0], np.loadtxt('data/tuf5000/log.txt', skiprows=1)[:, 1],
        label = 'tuf5000')
plt.legend()
plt.show()
